# %% [markdown]
# # Amazon Proj

# %% [markdown]
# ## Importazione e prima manipolazione dati

# %%
# !pip install openai
# Out:
# ...
#   Using cached openai-1.85.0-py3-none-any.whl.metadata (25 kB)
# ...
# Using cached openai-1.85.0-py3-none-any.whl (730 kB)
# ...

# %% [markdown]
# ### Importazione

# %%
# import librerie
import kagglehub
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = kagglehub.dataset_download("karkavelrajaj/amazon-sales-dataset")
print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\danie\.cache\kagglehub\datasets\karkavelrajaj\amazon-sales-dataset\versions\1

# %%
# Mostriamo tutti i file presenti nella cartella
files = os.listdir(path)
print("Files presenti:", files)
# Out:
# Files presenti: ['amazon.csv']

# %%
# Controlla TUTTI i file e sottocartelle ricorsivamente
for root, dirs, files in os.walk(path):
    for file in files:
        print(os.path.join(root, file))
# Out:
# C:\Users\danie\.cache\kagglehub\datasets\karkavelrajaj\amazon-sales-dataset\versions\1\amazon.csv

# %%
df = pd.read_csv(os.path.join(path, file))
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
#osserviamo i tipi di dati
df.dtypes
# Out:
# product_id             object
# product_name           object
# category               object
# discounted_price       object
# actual_price           object
# discount_percentage    object
# rating                 object
# rating_count           object
# about_product          object
# user_id                object
# user_name              object
# review_id              object
# review_title           object
# review_content         object
# img_link               object
# product_link           object
# dtype: object

# %% [markdown]
# ### Pulizia DF

# %%
# STEP 1: Convertiamo i valori in stringa
df['discounted_price'] = df['discounted_price'].astype(str)
df['actual_price'] = df['actual_price'].astype(str)

# STEP 2: Rimuoviamo il simbolo ₹, virgole e spazi
df['discounted_price'] = df['discounted_price'].str.replace('₹', '', regex=False).str.replace(',', '').str.strip()
df['actual_price'] = df['actual_price'].str.replace('₹', '', regex=False).str.replace(',', '').str.strip()

# STEP 3: Convertiamo in float
df['discounted_price'] = df['discounted_price'].astype(float)
df['actual_price'] = df['actual_price'].astype(float)

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price discount_percentage rating rating_count  \
# 0        1099.0                 64%    4.2       24,269
# ...

# %%
df['category'].unique()
# Out:
# array(['Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables',
#        'Computers&Accessories|NetworkingDevices|NetworkAdapters|WirelessUSBAdapters',
#        'Electronics|HomeTheater,TV&Video|Accessories|Cables|HDMICables',
#        'Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions',
#        'Electronics|HomeTheater,TV&Video|Accessories|RemoteControls',
#        'Electronics|HomeTheater,TV&Video|Televisions|StandardTelevisions',
#        'Electronics|HomeTheater,TV&Video|Accessories|TVMounts,Stands&Turntables|TVWall&CeilingMounts',
#        'Electronics|HomeTheater,TV&Video|Accessories|Cables|RCACables',
#        'Electronics|HomeAudio|Accessories|SpeakerAccessories|Mounts',
#        'Electronics|HomeTheater,TV&Video|Accessories|Cables|OpticalCables',
#        'Electronics|HomeTheater,TV&Video|Projectors',
#        'Electronics|HomeAudio|Accessories|Adapters',
# ...

# %%
# rating: da stringa a float (gestisce anche eventuali valori non convertibili)
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')

# rating_count: rimuove le virgole e converte in float
df['rating_count'] = df['rating_count'].astype(str).str.replace(',', '').astype(float)

# discount_percentage: rimuove il simbolo % e converte in float
df['discount_percentage'] = df['discount_percentage'].astype(str).str.replace('%', '').astype(int)

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                   64     4.2       24269.0
# ...

# %%
df.dtypes
# Out:
# product_id              object
# product_name            object
# category                object
# discounted_price       float64
# actual_price           float64
# discount_percentage      int32
# rating                 float64
# rating_count           float64
# about_product           object
# user_id                 object
# user_name               object
# review_id               object
# review_title            object
# review_content          object
# img_link                object
# product_link            object
# dtype: object

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
df['rating'].hist(bins=20, edgecolor='black')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.title('Istogramma della variabile rating')
plt.show()

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# rating_count           2
# rating                 1
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %% [markdown]
# ### Manipolazione dataset

# %%
df = df.rename(columns={'category': 'category1'})

# %%
# Estrai la prima e l'ultima categoria dalla colonna 'category'
df['Category'] = df['category1'].str.split('|').str[0]
df['Item'] = df['category1'].str.split('|').str[-1]

# %%
df = df.drop(columns=['category1'])
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#       discounted_price  actual_price  discount_percentage  rating  \
# 0                399.0        1099.0                   64     4.2
# ...

# %% [markdown]
# ## Analisi descrittiva

# %%
df.describe()
# Out:
#        discounted_price   actual_price  discount_percentage       rating  \
# count       1465.000000    1465.000000          1465.000000  1464.000000
# mean        3125.310874    5444.990635            47.691468     4.096585
# std         6944.304394   10874.826864            21.635905     0.291674
# min           39.000000      39.000000             0.000000     2.000000
# 25%          325.000000     800.000000            32.000000     4.000000
# 50%          799.000000    1650.000000            50.000000     4.100000
# 75%         1999.000000    4295.000000            63.000000     4.300000
# max        77990.000000  139900.000000            94.000000     5.000000
#
#         rating_count
# count    1463.000000
# mean    18295.541353
# std     42753.864952
# min         2.000000
# 25%      1186.000000
# 50%      5179.000000
# 75%     17336.500000
# max    426973.000000

# %% [markdown]
# actuval price sembra avere devi valori molto ampi, indagheremo se presenti outlier
# discounted price mostra chiaramente come molti prodotti sono stati fortemente scontati
# discount_percentage	mediana intorno al 50%, sconti tendenzialmente molto alti
# rating_count ha una fortissima asimmetria → prodotti virali con molte review, altri con pochissime

# %%
# verifichiamo se actual_price ha outliers

# Calcoliamo i quartili Q1 (25%) e Q3 (75%)
Q1 = df['actual_price'].quantile(0.25)
Q3 = df['actual_price'].quantile(0.75)

# Calcoliamo l'intervallo interquartile (IQR)
IQR = Q3 - Q1

# Definiamo i limiti oltre i quali consideriamo un valore come outlier
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Verifichiamo quanti valori sono outlier
outliers = df[(df['actual_price'] < lower_bound) | (df['actual_price'] > upper_bound)]

# Stampiamo il numero di outlier e mostriamo i primi 5
print(f"Numero di outlier in actual_price: {len(outliers)}")
print(outliers[['product_name', 'actual_price']].head())


# Visualizziamo i dati con un boxplot
plt.figure(figsize=(10, 1))
sns.boxplot(x=df['actual_price'])
plt.title("Boxplot di actual_price")
plt.show()
# Out:
# Numero di outlier in actual_price: 213
#                                          product_name  actual_price
# 16  MI 80 cm (32 inches) 5A Series HD Ready Smart ...       24999.0
# 19  LG 80 cm (32 inches) HD Ready Smart LED TV 32L...       21990.0
# 22  Samsung 80 cm (32 Inches) Wondertainment Serie...       22900.0
# 24  Acer 80 cm (32 inches) I Series HD Ready Andro...       19990.0
# 26  OnePlus 80 cm (32 inches) Y Series HD Ready LE...       19999.0

# %%
# x Luca --> capire se ci servono outliers o meno, dobbiamo creare modello predittivo o capire se la fascia di prezzo è giusta?

# %%
## segmentazione dei dati per fascia di prezzo

# Creiamo una nuova colonna 'price_range' per categorizzare i prezzi
df['price_range'] = 'Basso'  # inizializziamo tutto come 'Basso'

# Applichiamo le regole per le fasce di prezzo
df.loc[(df['actual_price'] >= 1000) & (df['actual_price'] <= 5000), 'price_range'] = 'Medio'
df.loc[(df['actual_price'] > 5000) & (df['actual_price'] <= 15000), 'price_range'] = 'Alto'
df.loc[df['actual_price'] > 15000, 'price_range'] = 'Premium'

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#       discounted_price  actual_price  discount_percentage  rating  \
# 0                399.0        1099.0                   64     4.2
# ...

# %%
# Analisi delle recensioni per Category

# Media del rating per categoria
media_rating = df.groupby('Category')['rating'].mean().sort_values(ascending=False)
print("Media rating per categoria:")
print(media_rating)

# Numero medio di recensioni per categoria
media_num_recensioni = df.groupby('Category')['rating_count'].mean().sort_values(ascending=False)
print("\nNumero medio di recensioni per categoria:")
print(media_num_recensioni)

# Visualizzazione con un barplot
plt.figure(figsize=(12,5))
sns.barplot(x=media_rating.index, y=media_rating.values)
plt.xticks(rotation=45)
plt.ylabel('Media Rating')
plt.title('Media rating per categoria')
plt.show()
# Out:
# Media rating per categoria:
# Category
# OfficeProducts           4.309677
# Toys&Games               4.300000
# HomeImprovement          4.250000
# Computers&Accessories    4.154967
# Electronics              4.081749
# Home&Kitchen             4.040716
# Health&PersonalCare      4.000000
# MusicalInstruments       3.900000
# Car&Motorbike            3.800000
# Name: rating, dtype: float64
#
# Numero medio di recensioni per categoria:
# Category
# MusicalInstruments       44441.000000
# Electronics              29997.809886
# Computers&Accessories    17136.782705
# Toys&Games               15867.000000
# Home&Kitchen              6676.493304
# OfficeProducts            4828.225806
# HomeImprovement           4283.000000
# Health&PersonalCare       3663.000000
# Car&Motorbike             1118.000000
# Name: rating_count, dtype: float64

# %%
# Trova il prodotto con rating più alto e più basso per ogni categoria

best_per_category = df.loc[df.groupby('Category')['rating'].idxmax()][['Category', 'product_name', 'rating']]
worst_per_category = df.loc[df.groupby('Category')['rating'].idxmin()][['Category', 'product_name', 'rating']]

print("Prodotti MIGLIORI per categoria:")
print(best_per_category)

print("\nProdotti PEGGIORI per categoria:")
print(worst_per_category)
# Out:
# Prodotti MIGLIORI per categoria:
#                    Category  \
# 1157          Car&Motorbike
# 174   Computers&Accessories
# 249             Electronics
# 1247    Health&PersonalCare
# 1145           Home&Kitchen
# 982         HomeImprovement
# 613      MusicalInstruments
# 637          OfficeProducts
# 924              Toys&Games
#
#                                            product_name  rating
# 1157  Reffair AX30 [MAX] Portable Air Purifier for C...     3.8
# 174   Syncwire LTG to USB Cable for Fast Charging Co...     5.0
# 249   Sony Bravia 164 cm (65 inches) 4K Ultra HD Sma...     4.7
# 1247  Dr Trust Electronic Kitchen Digital Scale Weig...     4.0
# 1145  Swiffer Instant Electric Water Heater Faucet T...     4.8
# 982   Gizga Essentials Cable Organiser, Cord Managem...     4.5
# 613   Boya ByM1 Auxiliary Omnidirectional Lavalier C...     4.0
# 637   Casio FX-991ES Plus-2nd Edition Scientific Cal...     4.5
# 924   Faber-Castell Connector Pen Set - Pack of 25 (...     4.3
# ...
